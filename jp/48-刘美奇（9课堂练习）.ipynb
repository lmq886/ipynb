# %%
import pymysql
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from copy import deepcopy
engine = create_engine('mysql+pymysql://root:root123ABC@@10.51.185.125:3306/lmq?charset=utf8')
engine
# Out:
# Engine(mysql+pymysql://root:***@10.51.185.125:3306/lmq?charset=utf8)

# %%
dataill_a = pd.read_sql('meal_order_detail1',con=engine)
dataill_b = pd.read_sql('meal_order_detail2',con=engine)
dataill_c = pd.read_sql('meal_order_detail3',con=engine)

# %%
dataill = pd.concat([dataill_a,dataill_b,dataill_c],axis=0,sort=False)

# %% [markdown]
# # 1

# %%
dataill
# Out:
#      detail_id order_id dishes_id logicprn_name parent_class_name  \
# 0         2956      417    610062            NA                NA
# 1         2958      417    609957            NA                NA
# 2         2961      417    609950            NA                NA
# 3         2966      417    610038            NA                NA
# 4         2968      417    610003            NA                NA
# ...        ...      ...       ...           ...               ...
# 3606      5683      672    610049            NA                NA
# 3607      5686      672    609959            NA                NA
# 3608      5379      647    610012            NA                NA
# 3609      5380      647    610054            NA                NA
# 3610      5688      672    609953            NA                NA
#
#            dishes_name itemis_add  counts  amounts cost    place_order_time  \
# 0                 蒜蓉生蚝          0     1.0     49.0   NA 2016-08-01 11:05:00
# ...

# %%
users = pd.read_excel(r'C:\Users\Administrator\Desktop\users.xlsx')

# %%
order = pd.read_csv(r'C:\Users\Administrator\Desktop\meal_order_info.csv',encoding='gbk')

# %%
dataill['emp_id']
order['emp_id']
users[]
# Out:
# 0      1442
# 1      1095
# 2      1147
# 3      1166
# 4      1094
#        ...
# 940    1095
# 941    1089
# 942    1155
# 943    1094
# 944    1113
# Name: emp_id, Length: 945, dtype: int64

# %%
data = pd.merge(users,order,left_on='USER_ID',right_on='emp_id')

# %%
data
# Out:
#      USER_ID MYID ACCOUNT  NAME  ORGANIZE_ID ORGANIZE_NAME  DUTY_ID  TITLE_ID  \
# 0        982  NaN     叶亦凯    sx          328           统计班      NaN       NaN
# 1        982  NaN     叶亦凯    sx          328           统计班      NaN       NaN
# 2        982  NaN     叶亦凯    sx          328           统计班      NaN       NaN
# 3        983  NaN     邓彬彬   lyy          328           统计班      NaN       NaN
# 4        984  NaN     张建涛   zad          328           统计班      NaN       NaN
# ..       ...  ...     ...   ...          ...           ...      ...       ...
# 940     1606  NaN     柴亮亮  a735          330         统计17级      NaN       NaN
# 941     1607  NaN     柴成立  a736          330         统计17级      NaN       NaN
# 942     1608  NaN     柴书琴  a737          330         统计17级      NaN       NaN
# 943     1609  NaN     柴豪逊  a738          330         统计17级      NaN       NaN
# 944     1610  NaN     柴观骁  a739          330         统计17级      NaN       NaN
#
# ...

# %% [markdown]
# # 2

# %%
csyye = pd.read_excel(r'D:\Desktop\超市营业额2.xlsx')
csyye2 = deepcopy(csyye)

# %%
A = csyye2.groupby(by='姓名')
A.sum()
# Out:
#        工号       交易额
# 姓名
# 周七  42210  50208.90
# 张三  38038  58130.00
# 李四  47094  58730.00
# 王五  40120  58892.00
# 赵六  45180  56069.00
# 钱八  37222  48813.45

# %%
yg1 = A.get_group("周七")['交易额'].mean()
for jye in A.get_group("周七")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
yg1 = A.get_group("张三")['交易额'].mean()
for jye in A.get_group("张三")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
yg1 = A.get_group("李四")['交易额'].mean()
for jye in A.get_group("李四")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
yg1 = A.get_group("王五")['交易额'].mean()
for jye in A.get_group("王五")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
yg1 = A.get_group("赵六")['交易额'].mean()
for jye in A.get_group("赵六")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
yg1 = A.get_group("钱八")['交易额'].mean()
for jye in A.get_group("钱八")['交易额'].isnull():
    csyye2['交易额'].fillna(yg1, inplace=True)

# %%
csyye2
# Out:
#        工号  姓名          日期           时段     交易额    柜台
# 0    1001  张三  2019-03-01   9：00-14：00  1664.0   化妆品
# 1    1002  李四  2019-03-01  14：00-21：00   954.0   化妆品
# 2    1003  王五  2019-03-01   9：00-14：00  1407.0    食品
# 3    1004  赵六  2019-03-01  14：00-21：00  1320.0    食品
# 4    1005  周七  2019-03-01   9：00-14：00   994.0   日用品
# ..    ...  ..         ...          ...     ...   ...
# 244  1002  李四  2019-03-31  14：00-21：00   859.0  蔬菜水果
# 245  1004  赵六  2019-03-31   9：00-14：00  1668.0   日用品
# 246  1004  赵六  2019-03-31  14：00-21：00  1722.0   日用品
# 247  1003  王五  2019-03-31   9：00-14：00  1274.0    食品
# 248  1006  钱八  2019-03-31  14：00-21：00   812.0    食品
#
# [249 rows x 6 columns]

# %%
A = csyye['姓名']['交易额']
[i for i in A]
# Out:
# [('周七', 4       994.0
#   12     1444.0
#   20     1592.0
#   23     1638.0
#   28     1346.0
#   31     1199.0
#   36     1249.0
#   44     1699.0
#   47     1778.0
#   52     1465.0
#   60     1029.0
#   68     1012.0
#   76       53.0
#   77      980.0
#   84      859.0
#   85     1633.0
#   92     1302.0
#   93     1317.0
#   101     922.0
#   102    1047.0
#   110       NaN
#   111    1387.0
#   118     916.0
#   119    1048.0
#   126    1246.0
#   127     887.0
#   135    1022.0
#   143    1329.0
#   151    1058.0
#   159    1046.0
#   167    1581.0
#   168       NaN
#   176    1437.0
#   184    1523.0
#   195     865.0
#   203    1006.0
#   211     866.0
#   219     871.0
#   227    1737.0
#   235    1070.0
#   241    1321.0
#   243    1044.0
#   Name: 交易额, dtype: float64), ('张三', 0       1664.0
#   7       1442.0
#   8       1530.0
#   16      1361.0
#   24      1216.0
#   32      1391.0
#   39       856.0
#   40      1037.0
#   54      1263.0
#   72      1456.0
# ...

# %%
count('a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-705f83893deb> in <module>
# ----> 1 count('a')
#
# NameError: name 'count' is not defined
